# %%
import pandas as pd

# %%
test = pd.read_csv('comp_links_dicts.csv')

# %%
test
# Out:
#                                                comp_link vehicleTransmission  \
# 0      https://auto.ru/catalog/cars/toyota/alphard/21...      автоматическая
# 1      https://auto.ru/catalog/cars/skoda/octavia/933...    роботизированная
# 2      https://auto.ru/catalog/cars/volkswagen/golf_g...    роботизированная
# 3      https://auto.ru/catalog/cars/skoda/yeti/603890...    роботизированная
# 4      https://auto.ru/catalog/cars/honda/partner/203...      автоматическая
# ...                                                  ...                 ...
# 11700  https://auto.ru/catalog/cars/toyota/carina/647...      автоматическая
# 11701  https://auto.ru/catalog/cars/mercedes/cls_klas...      автоматическая
# 11702  https://auto.ru/catalog/cars/toyota/crown/2035...      автоматическая
# 11703  https://auto.ru/catalog/cars/volvo/240_series/...        механическая
# 11704  https://auto.ru/catalog/cars/audi/80/7892649/7...      автоматическая
#
# ...

# %%
test01 = pd.read_csv('test.csv')

# %%
test01.columns
# Out:
# Index(['bodyType', 'brand', 'car_url', 'color', 'complectation_dict',
#        'description', 'engineDisplacement', 'enginePower', 'equipment_dict',
#        'fuelType', 'image', 'mileage', 'modelDate', 'model_info', 'model_name',
#        'name', 'numberOfDoors', 'parsing_unixtime', 'priceCurrency',
#        'productionDate', 'sell_id', 'super_gen', 'vehicleConfiguration',
#        'vehicleTransmission', 'vendor', 'Владельцы', 'Владение', 'ПТС',
#        'Привод', 'Руль', 'Состояние', 'Таможня'],
#       dtype='object')

# %%
test01['model_info']
# Out:
# 0        {"code":"OCTAVIA","name":"Octavia","ru_name":"...
# 1        {"code":"OCTAVIA","name":"Octavia","ru_name":"...
# 2        {"code":"SUPERB","name":"Superb","ru_name":"Су...
# 3        {"code":"OCTAVIA","name":"Octavia","ru_name":"...
# 4        {"code":"OCTAVIA","name":"Octavia","ru_name":"...
#                                ...
# 34681    {"code":"3ER","name":"3 серии","ru_name":"3 се...
# 34682    {"code":"5ER","name":"5 серии","ru_name":"5 се...
# 34683    {"code":"5ER","name":"5 серии","ru_name":"5 се...
# 34684    {"code":"X1","name":"X1","ru_name":"Х1","morph...
# 34685    {"code":"X5","name":"X5","ru_name":"Х5","morph...
# Name: model_info, Length: 34686, dtype: object
