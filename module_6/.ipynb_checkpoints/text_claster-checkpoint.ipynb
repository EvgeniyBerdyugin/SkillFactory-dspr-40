# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer

# %%
data = pd.read_csv('descriptoins.csv')

# %%
data = data.drop(lost_descript)

# %%
labels = data.cluster

# %%
# Создаём объект, который будет токенизировать данные
analyzer = CountVectorizer(stop_words='english').build_analyzer()

# Токенизируем наш набор данных
docs = []
for document in data.description:
    docs.append(analyzer(document.replace('_', '')))

# И посмотрим 10 первых примеров
for i in range(10):
    print(docs[i], end='\n\n')
# Out:
# ['все', 'автомобили', 'представленные', 'продаже', 'проходят', 'тщательную', 'проверку', 'по', 'более', '40', 'параметрам', 'предоставляем', 'гарантию', 'юридической', 'чистоты', 'так', 'же', 'год', 'технической', 'гарантии', 'на', 'двигатель', 'кпп', 'бесплатный', 'тест', 'драйв', 'возможно', 'оформление', 'автомобиля', 'кредит', 'преимущества', 'автокредитования', 'первоначальный', 'взнос', 'от', 'более', '30', 'кредитных', 'программ', 'процентная', 'ставка', 'от', 'годовых', 'срок', 'кредита', 'от', 'месяцев', 'до', 'лет', 'оформление', 'кредита', 'по', 'двум', 'документам', 'досрочное', 'погашение', 'без', 'штрафов', 'комиссий', 'сумма', 'кредита', 'до', 'млн', 'рублей', 'оформление', 'каско', 'по', 'желанию', 'без', 'справок', 'поручителей', 'сотрудничаем', '12', 'аккредитованными', 'сертифицированными', 'банками', 'рф', 'среднее', 'время', 'ожидания', 'решения', 'банка', '20', '30', 'минут', 'при', 'покупке', 'автомобиля', 'по', 'программе', 'trade', 'выгодный', 'обмен', 'или', 'кредит', 'получите', 'дополнительную', 'скидку', 'до', '80', '000', 'рублей', 'на', 'данный', 'автомобиль', 'записаться', 'на', 'тест', 'драйв', 'так', 'же', 'получить', 'подробную', 'информацию', 'можно', 'специалистов', 'автоцентра', 'по', 'указанному', 'номеру', 'телефона']
#
# ['лот', '01217195', 'автопрага', 'север', 'данный', 'автомобиль', 'прошел', 'диагностику', 'по', '147', 'пунктам', 'имеет', 'сертификат', 'технической', 'гарантии', 'вы', 'можете', 'получить', 'скидку', 'на', 'данный', 'автомобиль', 'до', '50000', 'рублей', 'подробности', 'уточняйте', 'менеджеров', 'отдела', 'продаж', 'гк', 'favorit', 'motors', 'строит', 'свою', 'работу', 'на', 'принципах', 'открытости', 'честности', 'нам', 'доверяют', 'более', '25', 'лет', 'автомобиль', 'продается', 'официальным', 'дилером', 'favorit', 'motors', 'покупка', 'обслуживание', 'официального', 'дилера', 'проведена', 'предпродажная', 'подготовка', 'гарантия', 'юридической', 'чистоты', 'круглосуточная', 'техническая', 'поддержка', 'бесплатным', 'эвакуатором', 'автомобиль', 'можно', 'приобрести', 'за', 'наличный', 'расчет', 'безналичным', 'платежом', 'также', 'мы', 'примем', 'вашу', 'машину', 'по', 'рыночной', 'стоимости', 'рамках', 'программы', 'трейд', 'ин', 'при', 'необходимости', 'выплатим', 'за', 'нее', 'кредит', 'возможна', 'покупка', 'кредит', 'специальные', 'предложения', 'по', 'кредитованию', 'страхованию', 'оформление', 'кредита', 'по', 'двум', 'документам', 'каско', 'не', 'обязательно', 'приглашаем', 'на', 'бесплатный', 'тест', 'драйв', 'группа', 'компаний', 'favorit', 'motors', 'один', 'из', 'крупнейших', 'российских', 'холдингов', 'официальный', 'дилер', 'известных', 'мировых', 'брендов', 'которые', 'обслуживаются', 'технических', 'центрах', 'гк', 'favorit', 'motors', 'рамках', 'официального', 'сервиса', 'мы', 'предлагаем', 'полный', 'комплекс', 'услуг', 'по', 'предпродажной', 'подготовке', 'последующему', 'сервису', 'группа', 'компаний', 'favorit', 'motors', 'занимает', 'лидирующее', 'положение', 'рейтинге', 'продаж', 'автомобилей', 'пробегом', 'по', 'москве', 'области', 'это', 'подтверждают', 'специализированные', 'исследования', 'рынка', 'за', 'последние', 'пять', 'лет', 'указывающие', 'на', 'самый', 'крупный', 'объем', 'реализации', 'комплектации', 'автомобиля', 'тип', 'обивки', 'салона', 'ткань', 'цвет', 'салона', 'темный', 'светодиодные', 'дневные', 'ходовые', 'огни', 'тип', 'фар', 'галогеновые', 'легкосплавные', 'диски', '16', 'штатная', 'сигнализация', 'иммобилайзер', 'бортовой', 'компьютер', 'система', 'контроля', 'давления', 'шинах', 'датчик', 'дождя', 'круиз', 'контроль', 'пассивный', 'обогрев', 'лобового', 'стекла', 'обогрев', 'зеркал', 'усилитель', 'руля', 'центральный', 'замок', 'противотуманные', 'фары', 'датчик', 'света', 'обогрев', 'руля', 'обогрев', 'передних', 'сидений', 'климат', 'климат', 'контроль', 'зонный', 'электропривод', 'зеркал', 'стеклоподъемники', 'электро', 'все', 'сиденье', 'водителя', 'ручная', 'регулировка', 'по', 'высоте', 'сиденье', 'пассажира', 'ручная', 'регулировка', 'регулировка', 'руля', 'двух', 'плоскостях', 'антиблокировочная', 'система', 'abs', 'антипробуксовочная', 'система', 'система', 'курсовой', 'устойчивости', 'подушки', 'безопасности', 'передние', 'боковые', 'задний', 'парковочный', 'радар', 'система', 'крепления', 'isofix', 'фронтальный', 'видеомонитор', 'bluetooth', 'usb', 'тип', 'открытия', 'задней', 'двери', 'подъемная', 'тип', 'передних', 'тормозов', 'дисковые', 'тип', 'задних', 'тормозов', 'дисковые', 'тип', 'гарантии', 'на', 'гарантии']
#
# ['все', 'автомобили', 'представленные', 'продаже', 'проходят', 'тщательную', 'проверку', 'по', 'более', '40', 'параметрам', 'предоставляем', 'гарантию', 'юридической', 'чистоты', 'так', 'же', 'год', 'технической', 'гарантии', 'на', 'двигатель', 'кпп', 'бесплатный', 'тест', 'драйв', 'возможно', 'оформление', 'автомобиля', 'кредит', 'преимущества', 'автокредитования', 'первоначальный', 'взнос', 'от', 'более', '30', 'кредитных', 'программ', 'процентная', 'ставка', 'от', 'годовых', 'срок', 'кредита', 'от', 'месяцев', 'до', 'лет', 'оформление', 'кредита', 'по', 'двум', 'документам', 'досрочное', 'погашение', 'без', 'штрафов', 'комиссий', 'сумма', 'кредита', 'до', 'млн', 'рублей', 'оформление', 'каско', 'по', 'желанию', 'без', 'справок', 'поручителей', 'сотрудничаем', '12', 'аккредитованными', 'сертифицированными', 'банками', 'рф', 'среднее', 'время', 'ожидания', 'решения', 'банка', '20', '30', 'минут', 'при', 'покупке', 'автомобиля', 'по', 'программе', 'trade', 'выгодный', 'обмен', 'или', 'кредит', 'получите', 'дополнительную', 'скидку', 'до', '80', '000', 'рублей', 'на', 'данный', 'автомобиль', 'записаться', 'на', 'тест', 'драйв', 'так', 'же', 'получить', 'подробную', 'информацию', 'можно', 'специалистов', 'автоцентра', 'по', 'указанному', 'номеру', 'телефона']
#
# ['комплект', 'зимней', 'летней', 'резины', 'по', 'сезону', 'подарок', 'рассрочка', 'на', 'автомобили', 'пробегом', 'срок', '12', '18', 'месяцев', 'первоначальный', 'взнос', 'от', 'сумма', 'рассрочки', 'от', '90', 'до', 'млн', 'от', 'метро', 'рязанский', 'проспект', 'бесплатный', 'проезд', 'до', 'автосалона', 'genzes', 'гарантия', 'на', 'автомобили', 'различных', 'марок', 'сроком', 'на', 'год', 'при', 'общем', 'пробеге', 'до', '150', '000', 'км', 'двигатель', 'бензиновый', 'или', 'дизельный', 'механическая', 'коробка', 'передач', 'автоматическая', 'коробка', 'передач', 'роботизированная', 'коробка', 'передач', 'вариатор', 'раздаточная', 'коробка', 'редуктор', 'заднего', 'моста', 'редуктор', 'переднего', 'моста', 'радиатор', 'системы', 'охлаждения', 'радиатор', 'кондиционера', 'дополнительные', 'комиссии', 'отсутствуют', 'комфортные', 'условия', 'выбора', 'бесплатный', 'wi', 'fi', 'уютное', 'кафе', 'клиентской', 'зоной', 'большая', 'удобная', 'парковка', 'выберите', 'подходящий', 'автомобиль', 'совершите', 'выгодную', 'покупку', 'течение', 'дня', 'все', 'автомобили', 'представленные', 'продаже', 'проходят', 'диагностику', 'по', 'более', '48', 'параметрам', 'результатами', 'диагностики', 'вы', 'можете', 'ознакомиться', 'при', 'осмотре', 'автомобиля', 'при', 'покупке', 'автомобиля', 'по', 'программе', 'trade', 'обмен', 'на', 'ваш', 'автомобиль', 'дополнительная', 'скидка', 'до', '80', '000', 'рублей', 'до', '100', '000', 'рублей', 'при', 'покупке', 'автомобиля', 'кредит', 'преимущества', 'автокредитования', 'ставка', 'по', 'кредиту', 'от', 'годовых', 'первоначальный', 'взнос', 'от', 'более', '23', 'кредитных', 'программ', 'минимальный', 'пакет', 'документов', 'паспорт', 'водительское', 'удостоверение', 'срок', 'кредита', 'от', 'месяцев', 'до', 'лет', 'сумма', 'кредита', 'от', '50', '000', 'руб', 'до', '000', '000', 'рублей', 'досрочное', 'погашение', 'без', 'штрафов', 'комиссий', 'каско', 'необязательно', 'аргументированный', 'торг', 'уместен', 'только', 'при', 'осмотре', 'приглашаем', 'вас', 'на', 'бесплатный', 'тест', 'драйв', 'ждем', 'вас', 'ежедневно', 'без', 'выходных', '00', 'до', '20', '00', 'вязовский', 'проезд', '12с1']
#
# ['лот', '01220889', 'автопрага', 'север', 'вы', 'можете', 'получить', 'скидку', 'на', 'данный', 'автомобиль', 'до', '50000', 'рублей', 'подробности', 'уточняйте', 'менеджеров', 'отдела', 'продаж', 'гк', 'favorit', 'motors', 'строит', 'свою', 'работу', 'на', 'принципах', 'открытости', 'честности', 'нам', 'доверяют', 'более', '25', 'лет', 'автомобиль', 'продается', 'официальным', 'дилером', 'favorit', 'motors', 'покупка', 'обслуживание', 'официального', 'дилера', 'проведена', 'предпродажная', 'подготовка', 'гарантия', 'юридической', 'чистоты', 'круглосуточная', 'техническая', 'поддержка', 'бесплатным', 'эвакуатором', 'автомобиль', 'можно', 'приобрести', 'за', 'наличный', 'расчет', 'безналичным', 'платежом', 'также', 'мы', 'примем', 'вашу', 'машину', 'по', 'рыночной', 'стоимости', 'рамках', 'программы', 'трейд', 'ин', 'при', 'необходимости', 'выплатим', 'за', 'нее', 'кредит', 'возможна', 'покупка', 'кредит', 'специальные', 'предложения', 'по', 'кредитованию', 'страхованию', 'оформление', 'кредита', 'по', 'двум', 'документам', 'каско', 'не', 'обязательно', 'приглашаем', 'на', 'бесплатный', 'тест', 'драйв', 'группа', 'компаний', 'favorit', 'motors', 'один', 'из', 'крупнейших', 'российских', 'холдингов', 'официальный', 'дилер', 'известных', 'мировых', 'брендов', 'которые', 'обслуживаются', 'технических', 'центрах', 'гк', 'favorit', 'motors', 'рамках', 'официального', 'сервиса', 'мы', 'предлагаем', 'полный', 'комплекс', 'услуг', 'по', 'предпродажной', 'подготовке', 'последующему', 'сервису', 'группа', 'компаний', 'favorit', 'motors', 'занимает', 'лидирующее', 'положение', 'рейтинге', 'продаж', 'автомобилей', 'пробегом', 'по', 'москве', 'области', 'это', 'подтверждают', 'специализированные', 'исследования', 'рынка', 'за', 'последние', 'пять', 'лет', 'указывающие', 'на', 'самый', 'крупный', 'объем', 'реализации', 'комплектации', 'автомобиля', 'тип', 'обивки', 'салона', 'ткань', 'цвет', 'салона', 'темный', 'тип', 'фар', 'галогеновые', 'легкосплавные', 'диски', '16', 'штатная', 'сигнализация', 'иммобилайзер', 'бортовой', 'компьютер', 'датчик', 'дождя', 'круиз', 'контроль', 'пассивный', 'обогрев', 'зеркал', 'усилитель', 'руля', 'центральный', 'замок', 'противотуманные', 'фары', 'датчик', 'света', 'обогрев', 'передних', 'сидений', 'климат', 'климат', 'контроль', 'зонный', 'электропривод', 'зеркал', 'стеклоподъемники', 'электро', 'все', 'сиденье', 'водителя', 'ручная', 'регулировка', 'по', 'высоте', 'сиденье', 'пассажира', 'ручная', 'регулировка', 'по', 'высоте', 'регулировка', 'руля', 'двух', 'плоскостях', 'антиблокировочная', 'система', 'abs', 'антипробуксовочная', 'система', 'система', 'курсовой', 'устойчивости', 'подушки', 'безопасности', 'передние', 'боковые', 'задний', 'парковочный', 'радар', 'система', 'крепления', 'isofix', 'cd', 'фронтальный', 'видеомонитор', 'тип', 'открытия', 'задней', 'двери', 'подъемная', 'тип', 'передних', 'тормозов', 'дисковые', 'тип', 'задних', 'тормозов', 'дисковые']
#
# ['продаю', 'свой', 'автомобиль', 'автомобиль', 'полностью', 'исправен', 'обслужен', 'состояние', 'авто', 'отличное', 'имеется', 'зимняя', 'резина', 'новая', 'отъездил', 'на', 'ней', 'пару', 'месяцев', 'автомобиль', 'очень', 'бодрый', 'динамичный', 'прошивку', 'не', 'делал', 'все', 'вопросы', 'по', 'телефону', 'оригинальный', 'птс', 'установлен', 'даунпайп', 'установлен', 'умный', 'отопитель', 'кузов', 'родной', 'краске', 'полный', 'комплект', 'ключей', 'документов', 'обмен', 'не', 'интересует']
#
# ['выгода', '60', '000', 'рублей', 'при', 'покупке', 'авто', 'trade', 'выгода', '120', '000', 'рублей', 'при', 'покупке', 'кредит', 'также', 'мы', 'дарим', 'набор', 'подарков', 'на', 'сумму', 'от', '30', '000', 'рублей', 'оформление', 'кредита', 'по', 'двум', 'документам', 'за', 'час', 'первоначальный', 'взнос', 'от', 'процентная', 'ставка', 'от', 'годовых', 'каско', 'не', 'обязательно', 'все', 'автомобили', 'представленные', 'продаже', 'проходят', 'диагностику', 'по', '47', 'пунктам', 'основываясь', 'на', 'предпродажной', 'подготовке', 'мы', 'предоставляем', 'год', 'технической', 'гарантии', 'на', 'автомобили', 'предоставляется', 'гарантия', 'юридической', 'чистоты', 'письменной', 'форме', 'приглашаем', 'на', 'бесплатный', 'тест', 'драйв', 'записаться', 'на', 'тест', 'драйв', 'также', 'получить', 'подробную', 'информацию', 'можно', 'специалистов', 'автоцентра', 'по', 'указанному', 'номеру', 'телефона']
#
# ['лот', '01214644', 'автопрага', 'юг', 'вы', 'можете', 'получить', 'скидку', 'на', 'данный', 'автомобиль', 'до', '50000', 'рублей', 'подробности', 'уточняйте', 'менеджеров', 'отдела', 'продаж', 'гк', 'favorit', 'motors', 'строит', 'свою', 'работу', 'на', 'принципах', 'открытости', 'честности', 'нам', 'доверяют', 'более', '25', 'лет', 'автомобиль', 'продается', 'официальным', 'дилером', 'favorit', 'motors', 'покупка', 'обслуживание', 'официального', 'дилера', 'проведена', 'предпродажная', 'подготовка', 'гарантия', 'юридической', 'чистоты', 'круглосуточная', 'техническая', 'поддержка', 'бесплатным', 'эвакуатором', 'автомобиль', 'можно', 'приобрести', 'за', 'наличный', 'расчет', 'безналичным', 'платежом', 'также', 'мы', 'примем', 'вашу', 'машину', 'по', 'рыночной', 'стоимости', 'рамках', 'программы', 'трейд', 'ин', 'при', 'необходимости', 'выплатим', 'за', 'нее', 'кредит', 'возможна', 'покупка', 'кредит', 'специальные', 'предложения', 'по', 'кредитованию', 'страхованию', 'оформление', 'кредита', 'по', 'двум', 'документам', 'каско', 'не', 'обязательно', 'приглашаем', 'на', 'бесплатный', 'тест', 'драйв', 'группа', 'компаний', 'favorit', 'motors', 'один', 'из', 'крупнейших', 'российских', 'холдингов', 'официальный', 'дилер', 'известных', 'мировых', 'брендов', 'которые', 'обслуживаются', 'технических', 'центрах', 'гк', 'favorit', 'motors', 'рамках', 'официального', 'сервиса', 'мы', 'предлагаем', 'полный', 'комплекс', 'услуг', 'по', 'предпродажной', 'подготовке', 'последующему', 'сервису', 'группа', 'компаний', 'favorit', 'motors', 'занимает', 'лидирующее', 'положение', 'рейтинге', 'продаж', 'автомобилей', 'пробегом', 'по', 'москве', 'области', 'это', 'подтверждают', 'специализированные', 'исследования', 'рынка', 'за', 'последние', 'пять', 'лет', 'указывающие', 'на', 'самый', 'крупный', 'объем', 'реализации', 'комплектации', 'автомобиля', 'тип', 'обивки', 'салона', 'ткань', 'цвет', 'салона', 'темный', 'тонированные', 'стекла', 'тип', 'фар', 'галогеновые', 'штатная', 'сигнализация', 'иммобилайзер', 'бортовой', 'компьютер', 'газобалонное', 'оборудование', 'датчик', 'дождя', 'обогрев', 'зеркал', 'усилитель', 'руля', 'центральный', 'замок', 'датчик', 'света', 'обогрев', 'передних', 'сидений', 'климат', 'кондиционер', 'электропривод', 'зеркал', 'стеклоподъемники', 'электро', 'все', 'сиденье', 'водителя', 'ручная', 'регулировка', 'по', 'высоте', 'сиденье', 'пассажира', 'ручная', 'регулировка', 'по', 'высоте', 'регулировка', 'руля', 'двух', 'плоскостях', 'антиблокировочная', 'система', 'abs', 'антипробуксовочная', 'система', 'подушки', 'безопасности', 'водителя', 'пассажира', 'система', 'крепления', 'isofix', 'cd', 'тип', 'открытия', 'задней', 'двери', 'подъемная', 'тип', 'передних', 'тормозов', 'дисковые', 'тип', 'задних', 'тормозов', 'дисковые']
#
# ['лот', '01217938', 'автопрага', 'север', 'данный', 'автомобиль', 'прошел', 'диагностику', 'по', '147', 'пунктам', 'имеет', 'сертификат', 'технической', 'гарантии', 'вы', 'можете', 'получить', 'скидку', 'на', 'данный', 'автомобиль', 'до', '50000', 'рублей', 'подробности', 'уточняйте', 'менеджеров', 'отдела', 'продаж', 'гк', 'favorit', 'motors', 'строит', 'свою', 'работу', 'на', 'принципах', 'открытости', 'честности', 'нам', 'доверяют', 'более', '25', 'лет', 'автомобиль', 'продается', 'официальным', 'дилером', 'favorit', 'motors', 'покупка', 'обслуживание', 'официального', 'дилера', 'проведена', 'предпродажная', 'подготовка', 'гарантия', 'юридической', 'чистоты', 'круглосуточная', 'техническая', 'поддержка', 'бесплатным', 'эвакуатором', 'автомобиль', 'можно', 'приобрести', 'за', 'наличный', 'расчет', 'безналичным', 'платежом', 'также', 'мы', 'примем', 'вашу', 'машину', 'по', 'рыночной', 'стоимости', 'рамках', 'программы', 'трейд', 'ин', 'при', 'необходимости', 'выплатим', 'за', 'нее', 'кредит', 'возможна', 'покупка', 'кредит', 'специальные', 'предложения', 'по', 'кредитованию', 'страхованию', 'оформление', 'кредита', 'по', 'двум', 'документам', 'каско', 'не', 'обязательно', 'приглашаем', 'на', 'бесплатный', 'тест', 'драйв', 'группа', 'компаний', 'favorit', 'motors', 'один', 'из', 'крупнейших', 'российских', 'холдингов', 'официальный', 'дилер', 'известных', 'мировых', 'брендов', 'которые', 'обслуживаются', 'технических', 'центрах', 'гк', 'favorit', 'motors', 'рамках', 'официального', 'сервиса', 'мы', 'предлагаем', 'полный', 'комплекс', 'услуг', 'по', 'предпродажной', 'подготовке', 'последующему', 'сервису', 'группа', 'компаний', 'favorit', 'motors', 'занимает', 'лидирующее', 'положение', 'рейтинге', 'продаж', 'автомобилей', 'пробегом', 'по', 'москве', 'области', 'это', 'подтверждают', 'специализированные', 'исследования', 'рынка', 'за', 'последние', 'пять', 'лет', 'указывающие', 'на', 'самый', 'крупный', 'объем', 'реализации', 'комплектации', 'автомобиля', 'тип', 'обивки', 'салона', 'ткань', 'цвет', 'салона', 'темный', 'светодиодные', 'дневные', 'ходовые', 'огни', 'тип', 'фар', 'галогеновые', 'легкосплавные', 'диски', '18', 'рейлинги', 'на', 'крыше', 'штатная', 'сигнализация', 'иммобилайзер', 'бортовой', 'компьютер', 'датчик', 'дождя', 'круиз', 'контроль', 'пассивный', 'обогрев', 'лобового', 'стекла', 'обогрев', 'зеркал', 'усилитель', 'руля', 'центральный', 'замок', 'противотуманные', 'фары', 'датчик', 'света', 'обогрев', 'форсунок', 'омывателя', 'лобового', 'стекла', 'обогрев', 'руля', 'обогрев', 'передних', 'сидений', 'обогрев', 'задних', 'сидений', 'климат', 'климат', 'контроль', 'зонный', 'электропривод', 'зеркал', 'стеклоподъемники', 'электро', 'все', 'сиденье', 'водителя', 'ручная', 'регулировка', 'по', 'высоте', 'сиденье', 'пассажира', 'ручная', 'регулировка', 'по', 'высоте', 'регулировка', 'руля', 'двух', 'плоскостях', 'антиблокировочная', 'система', 'abs', 'антипробуксовочная', 'система', 'система', 'курсовой', 'устойчивости', 'подушки', 'безопасности', 'передние', 'боковые', 'передний', 'парковочный', 'радар', 'задний', 'парковочный', 'радар', 'система', 'крепления', 'isofix', 'фронтальный', 'видеомонитор', 'bluetooth', 'usb', 'тип', 'открытия', 'задней', 'двери', 'подъемная', 'тип', 'передних', 'тормозов', 'дисковые', 'тип', 'задних', 'тормозов', 'дисковые', 'тип', 'гарантии', 'на', 'гарантии']
#
# ['лот', '01222831', 'автопрага', 'север', 'вы', 'можете', 'получить', 'скидку', 'на', 'данный', 'автомобиль', 'до', '50000', 'рублей', 'подробности', 'уточняйте', 'менеджеров', 'отдела', 'продаж', 'гк', 'favorit', 'motors', 'строит', 'свою', 'работу', 'на', 'принципах', 'открытости', 'честности', 'нам', 'доверяют', 'более', '25', 'лет', 'автомобиль', 'продается', 'официальным', 'дилером', 'favorit', 'motors', 'покупка', 'обслуживание', 'официального', 'дилера', 'проведена', 'предпродажная', 'подготовка', 'гарантия', 'юридической', 'чистоты', 'круглосуточная', 'техническая', 'поддержка', 'бесплатным', 'эвакуатором', 'автомобиль', 'можно', 'приобрести', 'за', 'наличный', 'расчет', 'безналичным', 'платежом', 'также', 'мы', 'примем', 'вашу', 'машину', 'по', 'рыночной', 'стоимости', 'рамках', 'программы', 'трейд', 'ин', 'при', 'необходимости', 'выплатим', 'за', 'нее', 'кредит', 'возможна', 'покупка', 'кредит', 'специальные', 'предложения', 'по', 'кредитованию', 'страхованию', 'оформление', 'кредита', 'по', 'двум', 'документам', 'каско', 'не', 'обязательно', 'приглашаем', 'на', 'бесплатный', 'тест', 'драйв', 'группа', 'компаний', 'favorit', 'motors', 'один', 'из', 'крупнейших', 'российских', 'холдингов', 'официальный', 'дилер', 'известных', 'мировых', 'брендов', 'которые', 'обслуживаются', 'технических', 'центрах', 'гк', 'favorit', 'motors', 'рамках', 'официального', 'сервиса', 'мы', 'предлагаем', 'полный', 'комплекс', 'услуг', 'по', 'предпродажной', 'подготовке', 'последующему', 'сервису', 'группа', 'компаний', 'favorit', 'motors', 'занимает', 'лидирующее', 'положение', 'рейтинге', 'продаж', 'автомобилей', 'пробегом', 'по', 'москве', 'области', 'это', 'подтверждают', 'специализированные', 'исследования', 'рынка', 'за', 'последние', 'пять', 'лет', 'указывающие', 'на', 'самый', 'крупный', 'объем', 'реализации', 'комплектации', 'автомобиля', 'тип', 'обивки', 'салона', 'ткань', 'цвет', 'салона', 'темный', 'тонированные', 'стекла', 'тип', 'фар', 'галогеновые', 'рейлинги', 'на', 'крыше', 'штатная', 'сигнализация', 'иммобилайзер', 'бортовой', 'компьютер', 'обогрев', 'зеркал', 'усилитель', 'руля', 'центральный', 'замок', 'противотуманные', 'фары', 'обогрев', 'передних', 'сидений', 'климат', 'кондиционер', 'электропривод', 'зеркал', 'стеклоподъемники', 'электро', 'передние', 'сиденье', 'водителя', 'ручная', 'регулировка', 'по', 'высоте', 'сиденье', 'пассажира', 'ручная', 'регулировка', 'регулировка', 'руля', 'двух', 'плоскостях', 'антиблокировочная', 'система', 'abs', 'антипробуксовочная', 'система', 'система', 'курсовой', 'устойчивости', 'подушки', 'безопасности', 'водителя', 'пассажира', 'система', 'крепления', 'isofix', 'cd', 'usb', 'тип', 'открытия', 'задней', 'двери', 'подъемная', 'сервисная', 'книжка', 'тип', 'передних', 'тормозов', 'дисковые', 'тип', 'задних', 'тормозов', 'дисковые']

# %%
from gensim.models import Word2Vec

# Обучаем модель векторайзера на нашем наборе данных
# На выходе мы получим вектор признаков для каждого слова
model = Word2Vec(docs, min_count=20, vector_size=50)

# Наивный подход к созданию единого эмбеддинга для документа – средний эмбеддинг по словам
def doc_vectorizer(doc, model):
    doc_vector = []
    num_words = 0
    for word in doc:
        try:
            if num_words == 0:
                doc_vector = model.wv[word]
            else:
                doc_vector = np.add(doc_vector, model.wv[word])
            num_words += 1
        except:
            pass
     
    return np.asarray(doc_vector) / num_words

# Составляем эмбеддинги для наших документов
X = []
for doc in docs:
    X.append(doc_vectorizer(doc, model))

# %%
# Проверим размер вектора для документа
print(np.asarray(X).shape)
# Out:
# (118411,)
# C:\Users\negat\anaconda3\lib\site-packages\numpy\core\_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)

# %%
s = []
for i in X:
    s.append(i.shape[0])
ds = pd.DataFrame(s)
lost_descript = ds[ds[0] == 0].index

# %%
ds.value_counts()
# Out:
# 50    118328
# 0         83
# dtype: int64

# %%
data = data.drop(lost_descript)

# %%
# Токенизируем наш набор данных
docs = []
for document in data.description:
    docs.append(analyzer(document.replace('_', '')))

# И посмотрим 10 первых примеров
for i in range(10):
    print(docs[i], end='\n\n')
# Out:
# ['все', 'автомобили', 'представленные', 'продаже', 'проходят', 'тщательную', 'проверку', 'по', 'более', '40', 'параметрам', 'предоставляем', 'гарантию', 'юридической', 'чистоты', 'так', 'же', 'год', 'технической', 'гарантии', 'на', 'двигатель', 'кпп', 'бесплатный', 'тест', 'драйв', 'возможно', 'оформление', 'автомобиля', 'кредит', 'преимущества', 'автокредитования', 'первоначальный', 'взнос', 'от', 'более', '30', 'кредитных', 'программ', 'процентная', 'ставка', 'от', 'годовых', 'срок', 'кредита', 'от', 'месяцев', 'до', 'лет', 'оформление', 'кредита', 'по', 'двум', 'документам', 'досрочное', 'погашение', 'без', 'штрафов', 'комиссий', 'сумма', 'кредита', 'до', 'млн', 'рублей', 'оформление', 'каско', 'по', 'желанию', 'без', 'справок', 'поручителей', 'сотрудничаем', '12', 'аккредитованными', 'сертифицированными', 'банками', 'рф', 'среднее', 'время', 'ожидания', 'решения', 'банка', '20', '30', 'минут', 'при', 'покупке', 'автомобиля', 'по', 'программе', 'trade', 'выгодный', 'обмен', 'или', 'кредит', 'получите', 'дополнительную', 'скидку', 'до', '80', '000', 'рублей', 'на', 'данный', 'автомобиль', 'записаться', 'на', 'тест', 'драйв', 'так', 'же', 'получить', 'подробную', 'информацию', 'можно', 'специалистов', 'автоцентра', 'по', 'указанному', 'номеру', 'телефона']
#
# ['лот', '01217195', 'автопрага', 'север', 'данный', 'автомобиль', 'прошел', 'диагностику', 'по', '147', 'пунктам', 'имеет', 'сертификат', 'технической', 'гарантии', 'вы', 'можете', 'получить', 'скидку', 'на', 'данный', 'автомобиль', 'до', '50000', 'рублей', 'подробности', 'уточняйте', 'менеджеров', 'отдела', 'продаж', 'гк', 'favorit', 'motors', 'строит', 'свою', 'работу', 'на', 'принципах', 'открытости', 'честности', 'нам', 'доверяют', 'более', '25', 'лет', 'автомобиль', 'продается', 'официальным', 'дилером', 'favorit', 'motors', 'покупка', 'обслуживание', 'официального', 'дилера', 'проведена', 'предпродажная', 'подготовка', 'гарантия', 'юридической', 'чистоты', 'круглосуточная', 'техническая', 'поддержка', 'бесплатным', 'эвакуатором', 'автомобиль', 'можно', 'приобрести', 'за', 'наличный', 'расчет', 'безналичным', 'платежом', 'также', 'мы', 'примем', 'вашу', 'машину', 'по', 'рыночной', 'стоимости', 'рамках', 'программы', 'трейд', 'ин', 'при', 'необходимости', 'выплатим', 'за', 'нее', 'кредит', 'возможна', 'покупка', 'кредит', 'специальные', 'предложения', 'по', 'кредитованию', 'страхованию', 'оформление', 'кредита', 'по', 'двум', 'документам', 'каско', 'не', 'обязательно', 'приглашаем', 'на', 'бесплатный', 'тест', 'драйв', 'группа', 'компаний', 'favorit', 'motors', 'один', 'из', 'крупнейших', 'российских', 'холдингов', 'официальный', 'дилер', 'известных', 'мировых', 'брендов', 'которые', 'обслуживаются', 'технических', 'центрах', 'гк', 'favorit', 'motors', 'рамках', 'официального', 'сервиса', 'мы', 'предлагаем', 'полный', 'комплекс', 'услуг', 'по', 'предпродажной', 'подготовке', 'последующему', 'сервису', 'группа', 'компаний', 'favorit', 'motors', 'занимает', 'лидирующее', 'положение', 'рейтинге', 'продаж', 'автомобилей', 'пробегом', 'по', 'москве', 'области', 'это', 'подтверждают', 'специализированные', 'исследования', 'рынка', 'за', 'последние', 'пять', 'лет', 'указывающие', 'на', 'самый', 'крупный', 'объем', 'реализации', 'комплектации', 'автомобиля', 'тип', 'обивки', 'салона', 'ткань', 'цвет', 'салона', 'темный', 'светодиодные', 'дневные', 'ходовые', 'огни', 'тип', 'фар', 'галогеновые', 'легкосплавные', 'диски', '16', 'штатная', 'сигнализация', 'иммобилайзер', 'бортовой', 'компьютер', 'система', 'контроля', 'давления', 'шинах', 'датчик', 'дождя', 'круиз', 'контроль', 'пассивный', 'обогрев', 'лобового', 'стекла', 'обогрев', 'зеркал', 'усилитель', 'руля', 'центральный', 'замок', 'противотуманные', 'фары', 'датчик', 'света', 'обогрев', 'руля', 'обогрев', 'передних', 'сидений', 'климат', 'климат', 'контроль', 'зонный', 'электропривод', 'зеркал', 'стеклоподъемники', 'электро', 'все', 'сиденье', 'водителя', 'ручная', 'регулировка', 'по', 'высоте', 'сиденье', 'пассажира', 'ручная', 'регулировка', 'регулировка', 'руля', 'двух', 'плоскостях', 'антиблокировочная', 'система', 'abs', 'антипробуксовочная', 'система', 'система', 'курсовой', 'устойчивости', 'подушки', 'безопасности', 'передние', 'боковые', 'задний', 'парковочный', 'радар', 'система', 'крепления', 'isofix', 'фронтальный', 'видеомонитор', 'bluetooth', 'usb', 'тип', 'открытия', 'задней', 'двери', 'подъемная', 'тип', 'передних', 'тормозов', 'дисковые', 'тип', 'задних', 'тормозов', 'дисковые', 'тип', 'гарантии', 'на', 'гарантии']
#
# ['все', 'автомобили', 'представленные', 'продаже', 'проходят', 'тщательную', 'проверку', 'по', 'более', '40', 'параметрам', 'предоставляем', 'гарантию', 'юридической', 'чистоты', 'так', 'же', 'год', 'технической', 'гарантии', 'на', 'двигатель', 'кпп', 'бесплатный', 'тест', 'драйв', 'возможно', 'оформление', 'автомобиля', 'кредит', 'преимущества', 'автокредитования', 'первоначальный', 'взнос', 'от', 'более', '30', 'кредитных', 'программ', 'процентная', 'ставка', 'от', 'годовых', 'срок', 'кредита', 'от', 'месяцев', 'до', 'лет', 'оформление', 'кредита', 'по', 'двум', 'документам', 'досрочное', 'погашение', 'без', 'штрафов', 'комиссий', 'сумма', 'кредита', 'до', 'млн', 'рублей', 'оформление', 'каско', 'по', 'желанию', 'без', 'справок', 'поручителей', 'сотрудничаем', '12', 'аккредитованными', 'сертифицированными', 'банками', 'рф', 'среднее', 'время', 'ожидания', 'решения', 'банка', '20', '30', 'минут', 'при', 'покупке', 'автомобиля', 'по', 'программе', 'trade', 'выгодный', 'обмен', 'или', 'кредит', 'получите', 'дополнительную', 'скидку', 'до', '80', '000', 'рублей', 'на', 'данный', 'автомобиль', 'записаться', 'на', 'тест', 'драйв', 'так', 'же', 'получить', 'подробную', 'информацию', 'можно', 'специалистов', 'автоцентра', 'по', 'указанному', 'номеру', 'телефона']
#
# ['комплект', 'зимней', 'летней', 'резины', 'по', 'сезону', 'подарок', 'рассрочка', 'на', 'автомобили', 'пробегом', 'срок', '12', '18', 'месяцев', 'первоначальный', 'взнос', 'от', 'сумма', 'рассрочки', 'от', '90', 'до', 'млн', 'от', 'метро', 'рязанский', 'проспект', 'бесплатный', 'проезд', 'до', 'автосалона', 'genzes', 'гарантия', 'на', 'автомобили', 'различных', 'марок', 'сроком', 'на', 'год', 'при', 'общем', 'пробеге', 'до', '150', '000', 'км', 'двигатель', 'бензиновый', 'или', 'дизельный', 'механическая', 'коробка', 'передач', 'автоматическая', 'коробка', 'передач', 'роботизированная', 'коробка', 'передач', 'вариатор', 'раздаточная', 'коробка', 'редуктор', 'заднего', 'моста', 'редуктор', 'переднего', 'моста', 'радиатор', 'системы', 'охлаждения', 'радиатор', 'кондиционера', 'дополнительные', 'комиссии', 'отсутствуют', 'комфортные', 'условия', 'выбора', 'бесплатный', 'wi', 'fi', 'уютное', 'кафе', 'клиентской', 'зоной', 'большая', 'удобная', 'парковка', 'выберите', 'подходящий', 'автомобиль', 'совершите', 'выгодную', 'покупку', 'течение', 'дня', 'все', 'автомобили', 'представленные', 'продаже', 'проходят', 'диагностику', 'по', 'более', '48', 'параметрам', 'результатами', 'диагностики', 'вы', 'можете', 'ознакомиться', 'при', 'осмотре', 'автомобиля', 'при', 'покупке', 'автомобиля', 'по', 'программе', 'trade', 'обмен', 'на', 'ваш', 'автомобиль', 'дополнительная', 'скидка', 'до', '80', '000', 'рублей', 'до', '100', '000', 'рублей', 'при', 'покупке', 'автомобиля', 'кредит', 'преимущества', 'автокредитования', 'ставка', 'по', 'кредиту', 'от', 'годовых', 'первоначальный', 'взнос', 'от', 'более', '23', 'кредитных', 'программ', 'минимальный', 'пакет', 'документов', 'паспорт', 'водительское', 'удостоверение', 'срок', 'кредита', 'от', 'месяцев', 'до', 'лет', 'сумма', 'кредита', 'от', '50', '000', 'руб', 'до', '000', '000', 'рублей', 'досрочное', 'погашение', 'без', 'штрафов', 'комиссий', 'каско', 'необязательно', 'аргументированный', 'торг', 'уместен', 'только', 'при', 'осмотре', 'приглашаем', 'вас', 'на', 'бесплатный', 'тест', 'драйв', 'ждем', 'вас', 'ежедневно', 'без', 'выходных', '00', 'до', '20', '00', 'вязовский', 'проезд', '12с1']
#
# ['лот', '01220889', 'автопрага', 'север', 'вы', 'можете', 'получить', 'скидку', 'на', 'данный', 'автомобиль', 'до', '50000', 'рублей', 'подробности', 'уточняйте', 'менеджеров', 'отдела', 'продаж', 'гк', 'favorit', 'motors', 'строит', 'свою', 'работу', 'на', 'принципах', 'открытости', 'честности', 'нам', 'доверяют', 'более', '25', 'лет', 'автомобиль', 'продается', 'официальным', 'дилером', 'favorit', 'motors', 'покупка', 'обслуживание', 'официального', 'дилера', 'проведена', 'предпродажная', 'подготовка', 'гарантия', 'юридической', 'чистоты', 'круглосуточная', 'техническая', 'поддержка', 'бесплатным', 'эвакуатором', 'автомобиль', 'можно', 'приобрести', 'за', 'наличный', 'расчет', 'безналичным', 'платежом', 'также', 'мы', 'примем', 'вашу', 'машину', 'по', 'рыночной', 'стоимости', 'рамках', 'программы', 'трейд', 'ин', 'при', 'необходимости', 'выплатим', 'за', 'нее', 'кредит', 'возможна', 'покупка', 'кредит', 'специальные', 'предложения', 'по', 'кредитованию', 'страхованию', 'оформление', 'кредита', 'по', 'двум', 'документам', 'каско', 'не', 'обязательно', 'приглашаем', 'на', 'бесплатный', 'тест', 'драйв', 'группа', 'компаний', 'favorit', 'motors', 'один', 'из', 'крупнейших', 'российских', 'холдингов', 'официальный', 'дилер', 'известных', 'мировых', 'брендов', 'которые', 'обслуживаются', 'технических', 'центрах', 'гк', 'favorit', 'motors', 'рамках', 'официального', 'сервиса', 'мы', 'предлагаем', 'полный', 'комплекс', 'услуг', 'по', 'предпродажной', 'подготовке', 'последующему', 'сервису', 'группа', 'компаний', 'favorit', 'motors', 'занимает', 'лидирующее', 'положение', 'рейтинге', 'продаж', 'автомобилей', 'пробегом', 'по', 'москве', 'области', 'это', 'подтверждают', 'специализированные', 'исследования', 'рынка', 'за', 'последние', 'пять', 'лет', 'указывающие', 'на', 'самый', 'крупный', 'объем', 'реализации', 'комплектации', 'автомобиля', 'тип', 'обивки', 'салона', 'ткань', 'цвет', 'салона', 'темный', 'тип', 'фар', 'галогеновые', 'легкосплавные', 'диски', '16', 'штатная', 'сигнализация', 'иммобилайзер', 'бортовой', 'компьютер', 'датчик', 'дождя', 'круиз', 'контроль', 'пассивный', 'обогрев', 'зеркал', 'усилитель', 'руля', 'центральный', 'замок', 'противотуманные', 'фары', 'датчик', 'света', 'обогрев', 'передних', 'сидений', 'климат', 'климат', 'контроль', 'зонный', 'электропривод', 'зеркал', 'стеклоподъемники', 'электро', 'все', 'сиденье', 'водителя', 'ручная', 'регулировка', 'по', 'высоте', 'сиденье', 'пассажира', 'ручная', 'регулировка', 'по', 'высоте', 'регулировка', 'руля', 'двух', 'плоскостях', 'антиблокировочная', 'система', 'abs', 'антипробуксовочная', 'система', 'система', 'курсовой', 'устойчивости', 'подушки', 'безопасности', 'передние', 'боковые', 'задний', 'парковочный', 'радар', 'система', 'крепления', 'isofix', 'cd', 'фронтальный', 'видеомонитор', 'тип', 'открытия', 'задней', 'двери', 'подъемная', 'тип', 'передних', 'тормозов', 'дисковые', 'тип', 'задних', 'тормозов', 'дисковые']
#
# ['продаю', 'свой', 'автомобиль', 'автомобиль', 'полностью', 'исправен', 'обслужен', 'состояние', 'авто', 'отличное', 'имеется', 'зимняя', 'резина', 'новая', 'отъездил', 'на', 'ней', 'пару', 'месяцев', 'автомобиль', 'очень', 'бодрый', 'динамичный', 'прошивку', 'не', 'делал', 'все', 'вопросы', 'по', 'телефону', 'оригинальный', 'птс', 'установлен', 'даунпайп', 'установлен', 'умный', 'отопитель', 'кузов', 'родной', 'краске', 'полный', 'комплект', 'ключей', 'документов', 'обмен', 'не', 'интересует']
#
# ['выгода', '60', '000', 'рублей', 'при', 'покупке', 'авто', 'trade', 'выгода', '120', '000', 'рублей', 'при', 'покупке', 'кредит', 'также', 'мы', 'дарим', 'набор', 'подарков', 'на', 'сумму', 'от', '30', '000', 'рублей', 'оформление', 'кредита', 'по', 'двум', 'документам', 'за', 'час', 'первоначальный', 'взнос', 'от', 'процентная', 'ставка', 'от', 'годовых', 'каско', 'не', 'обязательно', 'все', 'автомобили', 'представленные', 'продаже', 'проходят', 'диагностику', 'по', '47', 'пунктам', 'основываясь', 'на', 'предпродажной', 'подготовке', 'мы', 'предоставляем', 'год', 'технической', 'гарантии', 'на', 'автомобили', 'предоставляется', 'гарантия', 'юридической', 'чистоты', 'письменной', 'форме', 'приглашаем', 'на', 'бесплатный', 'тест', 'драйв', 'записаться', 'на', 'тест', 'драйв', 'также', 'получить', 'подробную', 'информацию', 'можно', 'специалистов', 'автоцентра', 'по', 'указанному', 'номеру', 'телефона']
#
# ['лот', '01214644', 'автопрага', 'юг', 'вы', 'можете', 'получить', 'скидку', 'на', 'данный', 'автомобиль', 'до', '50000', 'рублей', 'подробности', 'уточняйте', 'менеджеров', 'отдела', 'продаж', 'гк', 'favorit', 'motors', 'строит', 'свою', 'работу', 'на', 'принципах', 'открытости', 'честности', 'нам', 'доверяют', 'более', '25', 'лет', 'автомобиль', 'продается', 'официальным', 'дилером', 'favorit', 'motors', 'покупка', 'обслуживание', 'официального', 'дилера', 'проведена', 'предпродажная', 'подготовка', 'гарантия', 'юридической', 'чистоты', 'круглосуточная', 'техническая', 'поддержка', 'бесплатным', 'эвакуатором', 'автомобиль', 'можно', 'приобрести', 'за', 'наличный', 'расчет', 'безналичным', 'платежом', 'также', 'мы', 'примем', 'вашу', 'машину', 'по', 'рыночной', 'стоимости', 'рамках', 'программы', 'трейд', 'ин', 'при', 'необходимости', 'выплатим', 'за', 'нее', 'кредит', 'возможна', 'покупка', 'кредит', 'специальные', 'предложения', 'по', 'кредитованию', 'страхованию', 'оформление', 'кредита', 'по', 'двум', 'документам', 'каско', 'не', 'обязательно', 'приглашаем', 'на', 'бесплатный', 'тест', 'драйв', 'группа', 'компаний', 'favorit', 'motors', 'один', 'из', 'крупнейших', 'российских', 'холдингов', 'официальный', 'дилер', 'известных', 'мировых', 'брендов', 'которые', 'обслуживаются', 'технических', 'центрах', 'гк', 'favorit', 'motors', 'рамках', 'официального', 'сервиса', 'мы', 'предлагаем', 'полный', 'комплекс', 'услуг', 'по', 'предпродажной', 'подготовке', 'последующему', 'сервису', 'группа', 'компаний', 'favorit', 'motors', 'занимает', 'лидирующее', 'положение', 'рейтинге', 'продаж', 'автомобилей', 'пробегом', 'по', 'москве', 'области', 'это', 'подтверждают', 'специализированные', 'исследования', 'рынка', 'за', 'последние', 'пять', 'лет', 'указывающие', 'на', 'самый', 'крупный', 'объем', 'реализации', 'комплектации', 'автомобиля', 'тип', 'обивки', 'салона', 'ткань', 'цвет', 'салона', 'темный', 'тонированные', 'стекла', 'тип', 'фар', 'галогеновые', 'штатная', 'сигнализация', 'иммобилайзер', 'бортовой', 'компьютер', 'газобалонное', 'оборудование', 'датчик', 'дождя', 'обогрев', 'зеркал', 'усилитель', 'руля', 'центральный', 'замок', 'датчик', 'света', 'обогрев', 'передних', 'сидений', 'климат', 'кондиционер', 'электропривод', 'зеркал', 'стеклоподъемники', 'электро', 'все', 'сиденье', 'водителя', 'ручная', 'регулировка', 'по', 'высоте', 'сиденье', 'пассажира', 'ручная', 'регулировка', 'по', 'высоте', 'регулировка', 'руля', 'двух', 'плоскостях', 'антиблокировочная', 'система', 'abs', 'антипробуксовочная', 'система', 'подушки', 'безопасности', 'водителя', 'пассажира', 'система', 'крепления', 'isofix', 'cd', 'тип', 'открытия', 'задней', 'двери', 'подъемная', 'тип', 'передних', 'тормозов', 'дисковые', 'тип', 'задних', 'тормозов', 'дисковые']
#
# ['лот', '01217938', 'автопрага', 'север', 'данный', 'автомобиль', 'прошел', 'диагностику', 'по', '147', 'пунктам', 'имеет', 'сертификат', 'технической', 'гарантии', 'вы', 'можете', 'получить', 'скидку', 'на', 'данный', 'автомобиль', 'до', '50000', 'рублей', 'подробности', 'уточняйте', 'менеджеров', 'отдела', 'продаж', 'гк', 'favorit', 'motors', 'строит', 'свою', 'работу', 'на', 'принципах', 'открытости', 'честности', 'нам', 'доверяют', 'более', '25', 'лет', 'автомобиль', 'продается', 'официальным', 'дилером', 'favorit', 'motors', 'покупка', 'обслуживание', 'официального', 'дилера', 'проведена', 'предпродажная', 'подготовка', 'гарантия', 'юридической', 'чистоты', 'круглосуточная', 'техническая', 'поддержка', 'бесплатным', 'эвакуатором', 'автомобиль', 'можно', 'приобрести', 'за', 'наличный', 'расчет', 'безналичным', 'платежом', 'также', 'мы', 'примем', 'вашу', 'машину', 'по', 'рыночной', 'стоимости', 'рамках', 'программы', 'трейд', 'ин', 'при', 'необходимости', 'выплатим', 'за', 'нее', 'кредит', 'возможна', 'покупка', 'кредит', 'специальные', 'предложения', 'по', 'кредитованию', 'страхованию', 'оформление', 'кредита', 'по', 'двум', 'документам', 'каско', 'не', 'обязательно', 'приглашаем', 'на', 'бесплатный', 'тест', 'драйв', 'группа', 'компаний', 'favorit', 'motors', 'один', 'из', 'крупнейших', 'российских', 'холдингов', 'официальный', 'дилер', 'известных', 'мировых', 'брендов', 'которые', 'обслуживаются', 'технических', 'центрах', 'гк', 'favorit', 'motors', 'рамках', 'официального', 'сервиса', 'мы', 'предлагаем', 'полный', 'комплекс', 'услуг', 'по', 'предпродажной', 'подготовке', 'последующему', 'сервису', 'группа', 'компаний', 'favorit', 'motors', 'занимает', 'лидирующее', 'положение', 'рейтинге', 'продаж', 'автомобилей', 'пробегом', 'по', 'москве', 'области', 'это', 'подтверждают', 'специализированные', 'исследования', 'рынка', 'за', 'последние', 'пять', 'лет', 'указывающие', 'на', 'самый', 'крупный', 'объем', 'реализации', 'комплектации', 'автомобиля', 'тип', 'обивки', 'салона', 'ткань', 'цвет', 'салона', 'темный', 'светодиодные', 'дневные', 'ходовые', 'огни', 'тип', 'фар', 'галогеновые', 'легкосплавные', 'диски', '18', 'рейлинги', 'на', 'крыше', 'штатная', 'сигнализация', 'иммобилайзер', 'бортовой', 'компьютер', 'датчик', 'дождя', 'круиз', 'контроль', 'пассивный', 'обогрев', 'лобового', 'стекла', 'обогрев', 'зеркал', 'усилитель', 'руля', 'центральный', 'замок', 'противотуманные', 'фары', 'датчик', 'света', 'обогрев', 'форсунок', 'омывателя', 'лобового', 'стекла', 'обогрев', 'руля', 'обогрев', 'передних', 'сидений', 'обогрев', 'задних', 'сидений', 'климат', 'климат', 'контроль', 'зонный', 'электропривод', 'зеркал', 'стеклоподъемники', 'электро', 'все', 'сиденье', 'водителя', 'ручная', 'регулировка', 'по', 'высоте', 'сиденье', 'пассажира', 'ручная', 'регулировка', 'по', 'высоте', 'регулировка', 'руля', 'двух', 'плоскостях', 'антиблокировочная', 'система', 'abs', 'антипробуксовочная', 'система', 'система', 'курсовой', 'устойчивости', 'подушки', 'безопасности', 'передние', 'боковые', 'передний', 'парковочный', 'радар', 'задний', 'парковочный', 'радар', 'система', 'крепления', 'isofix', 'фронтальный', 'видеомонитор', 'bluetooth', 'usb', 'тип', 'открытия', 'задней', 'двери', 'подъемная', 'тип', 'передних', 'тормозов', 'дисковые', 'тип', 'задних', 'тормозов', 'дисковые', 'тип', 'гарантии', 'на', 'гарантии']
#
# ['лот', '01222831', 'автопрага', 'север', 'вы', 'можете', 'получить', 'скидку', 'на', 'данный', 'автомобиль', 'до', '50000', 'рублей', 'подробности', 'уточняйте', 'менеджеров', 'отдела', 'продаж', 'гк', 'favorit', 'motors', 'строит', 'свою', 'работу', 'на', 'принципах', 'открытости', 'честности', 'нам', 'доверяют', 'более', '25', 'лет', 'автомобиль', 'продается', 'официальным', 'дилером', 'favorit', 'motors', 'покупка', 'обслуживание', 'официального', 'дилера', 'проведена', 'предпродажная', 'подготовка', 'гарантия', 'юридической', 'чистоты', 'круглосуточная', 'техническая', 'поддержка', 'бесплатным', 'эвакуатором', 'автомобиль', 'можно', 'приобрести', 'за', 'наличный', 'расчет', 'безналичным', 'платежом', 'также', 'мы', 'примем', 'вашу', 'машину', 'по', 'рыночной', 'стоимости', 'рамках', 'программы', 'трейд', 'ин', 'при', 'необходимости', 'выплатим', 'за', 'нее', 'кредит', 'возможна', 'покупка', 'кредит', 'специальные', 'предложения', 'по', 'кредитованию', 'страхованию', 'оформление', 'кредита', 'по', 'двум', 'документам', 'каско', 'не', 'обязательно', 'приглашаем', 'на', 'бесплатный', 'тест', 'драйв', 'группа', 'компаний', 'favorit', 'motors', 'один', 'из', 'крупнейших', 'российских', 'холдингов', 'официальный', 'дилер', 'известных', 'мировых', 'брендов', 'которые', 'обслуживаются', 'технических', 'центрах', 'гк', 'favorit', 'motors', 'рамках', 'официального', 'сервиса', 'мы', 'предлагаем', 'полный', 'комплекс', 'услуг', 'по', 'предпродажной', 'подготовке', 'последующему', 'сервису', 'группа', 'компаний', 'favorit', 'motors', 'занимает', 'лидирующее', 'положение', 'рейтинге', 'продаж', 'автомобилей', 'пробегом', 'по', 'москве', 'области', 'это', 'подтверждают', 'специализированные', 'исследования', 'рынка', 'за', 'последние', 'пять', 'лет', 'указывающие', 'на', 'самый', 'крупный', 'объем', 'реализации', 'комплектации', 'автомобиля', 'тип', 'обивки', 'салона', 'ткань', 'цвет', 'салона', 'темный', 'тонированные', 'стекла', 'тип', 'фар', 'галогеновые', 'рейлинги', 'на', 'крыше', 'штатная', 'сигнализация', 'иммобилайзер', 'бортовой', 'компьютер', 'обогрев', 'зеркал', 'усилитель', 'руля', 'центральный', 'замок', 'противотуманные', 'фары', 'обогрев', 'передних', 'сидений', 'климат', 'кондиционер', 'электропривод', 'зеркал', 'стеклоподъемники', 'электро', 'передние', 'сиденье', 'водителя', 'ручная', 'регулировка', 'по', 'высоте', 'сиденье', 'пассажира', 'ручная', 'регулировка', 'регулировка', 'руля', 'двух', 'плоскостях', 'антиблокировочная', 'система', 'abs', 'антипробуксовочная', 'система', 'система', 'курсовой', 'устойчивости', 'подушки', 'безопасности', 'водителя', 'пассажира', 'система', 'крепления', 'isofix', 'cd', 'usb', 'тип', 'открытия', 'задней', 'двери', 'подъемная', 'сервисная', 'книжка', 'тип', 'передних', 'тормозов', 'дисковые', 'тип', 'задних', 'тормозов', 'дисковые']

# %%
# Обучаем модель векторайзера на нашем наборе данных
# На выходе мы получим вектор признаков для каждого слова
model = Word2Vec(docs, min_count=20, vector_size=50)

# Наивный подход к созданию единого эмбеддинга для документа – средний эмбеддинг по словам
def doc_vectorizer(doc, model):
    doc_vector = []
    num_words = 0
    for word in doc:
        try:
            if num_words == 0:
                doc_vector = model.wv[word]
            else:
                doc_vector = np.add(doc_vector, model.wv[word])
            num_words += 1
        except:
            pass
     
    return np.asarray(doc_vector) / num_words

# Составляем эмбеддинги для наших документов
X = []
for doc in docs:
    X.append(doc_vectorizer(doc, model))

# %%
# Проверим размер вектора для документа
print(np.asarray(X).shape)
# Out:
# (118328, 50)

# %%
# t-SNE – метод понижения размерности
from sklearn.manifold import TSNE

# Создаём объект для выполнения t-SNE
tsne = TSNE(n_components=2, random_state=0)

# Преобразуем наши данные, понизив размерность с 50 до 2
X = tsne.fit_transform(X)

print(np.asarray(X).shape)
# Out:
# (118328, 2)

# %%
# # Создаём KMeans кластеризатор 
# kmeans = KMeans(n_clusters=6)

# # Обучим кластеризатор на подготовленных данных
# kmeans.fit(X)

# from sklearn.cluster import MiniBatchKMeans

# # Получаем предсказанные кластеры
# y_pred = kmeans.labels_.astype(int)

# # Координаты полученных центроидов
# print ("Координаты центроидов:\n", kmeans.cluster_centers_)

# MBKMeans = MiniBatchKMeans(n_clusters=3, 
#                            init='k-means++', 
#                            max_iter=500, 
#                            batch_size=1024, 
#                            verbose=0,
#                            compute_labels=True, 
#                            random_state=None, tol=0.0, 
#                            max_no_improvement=10, 
#                            init_size=None, 
#                            n_init=3, 
#                            reassignment_ratio=0.01)

# MBKMeans.fit(X)

# # Получаем предсказанные кластеры
# y_pred = MBKMeans.labels_.astype(int)

# # Координаты полученных центроидов
# print ("Координаты центроидов:\n", MBKMeans.cluster_centers_)
# Out:
# KMeans(n_clusters=6)

# %%
# from sklearn.mixture import GaussianMixture

# em_gm = GaussianMixture(n_components=3, 
#                         max_iter=500,
#                         init_params='kmeans', # 'kmeans’, ‘random’
#                         covariance_type='full', # ‘full’, ‘tied’, ‘diag’, ‘spherical’
#                         tol=0.001, 
#                         reg_covar=1e-06, 
#                         n_init=1, 
#                         weights_init=None, 
#                         means_init=None, 
#                         precisions_init=None, 
#                         random_state=None, 
#                         warm_start=False, 
#                         verbose=0, 
#                         verbose_interval=10
#                        )

# em_gm.fit(X)
# y_pred = em_gm.predict(X)

# %%
from sklearn.neighbors import kneighbors_graph

# %%
# строим матрицу смежности
connectivity = kneighbors_graph(X, n_neighbors=23, include_self=True)
# делаем матрицу смежности симметричной
connectivity = 0.5 * (connectivity + connectivity.T)

from sklearn.cluster import AgglomerativeClustering

ac = AgglomerativeClustering(n_clusters=6,
                             affinity='euclidean', # “euclidean”, “l1”, “l2”, “manhattan”, 
                                                   # “cosine”, or “precomputed”
                             linkage='average', # “ward”, “complete”, “average”, “single”
                             connectivity=connectivity
                            )

ac.fit(X)
y_pred = ac.labels_.astype(np.int)

# Графики полученных кластеров
plt.rcParams['figure.figsize'] = 10, 10
plt.scatter(X[:, 0], X[:, 1], c=y_pred, s=1, alpha=.5)
# plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', s=200, marker='+')
# plt.show()
# Out:
# C:\Users\negat\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py:501: UserWarning: the number of connected components of the connectivity matrix is 249 > 1. Completing it to avoid stopping the tree early.
#   connectivity, n_connected_components = _fix_connectivity(
# <ipython-input-29-2b1751b557e6>:16: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_pred = ac.labels_.astype(np.int)

# %%
# # строим матрицу смежности
# connectivity = kneighbors_graph(X, n_neighbors=4, include_self=False)
# # делаем матрицу смежности симметричной
# connectivity = 0.5 * (connectivity + connectivity.T)

# from sklearn.cluster import AgglomerativeClustering

# ac = AgglomerativeClustering(n_clusters=3,
#                              affinity='l1', # “euclidean”, “l1”, “l2”, “manhattan”, 
#                                                    # “cosine”, or “precomputed”
#                              linkage='complete', # “ward”, “complete”, “average”, “single”
#                              connectivity=connectivity
#                             )

# ac.fit(X)
# y_pred = ac.labels_.astype(np.int)

# # Графики полученных кластеров
# plt.rcParams['figure.figsize'] = 10, 10
# plt.scatter(X[:, 0], X[:, 1], c=y_pred, s=1, alpha=.5)
# Out:
# C:\Users\negat\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py:501: UserWarning: the number of connected components of the connectivity matrix is 1467 > 1. Completing it to avoid stopping the tree early.
#   connectivity, n_connected_components = _fix_connectivity(
# <ipython-input-252-4c7f9b244e32>:16: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_pred = ac.labels_.astype(np.int)

# %%
# # строим матрицу смежности
# connectivity = kneighbors_graph(X, n_neighbors=50, include_self=False)
# # делаем матрицу смежности симметричной
# connectivity = 0.5 * (connectivity + connectivity.T)
# ac = AgglomerativeClustering(n_clusters=None,
#                              distance_threshold=30,
#                              affinity='euclidean', # “euclidean”, “l1”, “l2”, “manhattan”, 
#                                                    # “cosine”, or “precomputed”
#                              linkage='average', # “ward”, “complete”, “average”, “single”
#                              connectivity=connectivity
#                             )
# ac.fit(X)
# y_pred = ac.labels_.astype(np.int)
# # Графики полученных кластеров
# plt.rcParams['figure.figsize'] = 10, 10
# plt.scatter(X[:, 0], X[:, 1], c=y_pred, s=1, alpha=.5)
# Out:
# C:\Users\negat\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py:501: UserWarning: the number of connected components of the connectivity matrix is 110 > 1. Completing it to avoid stopping the tree early.
#   connectivity, n_connected_components = _fix_connectivity(
# <ipython-input-220-4a5272b0019b>:13: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_pred = ac.labels_.astype(np.int)

# %%
# # строим матрицу смежности
# connectivity = kneighbors_graph(X, n_neighbors=44, include_self=False)
# # делаем матрицу смежности симметричной
# connectivity = 0.5 * (connectivity + connectivity.T)
# ac = AgglomerativeClustering(n_clusters=3, #None
#                              affinity='euclidean', # “euclidean”, “l1”, “l2”, “manhattan”, 
#                                                    # “cosine”, or “precomputed”
#                              linkage='average', # “ward”, “complete”, “average”, “single”
#                              connectivity=connectivity
#                             )
# ac.fit(X)
# y_pred = ac.labels_.astype(np.int)
# # Графики полученных кластеров
# plt.rcParams['figure.figsize'] = 10, 10
# plt.scatter(X[:, 0], X[:, 1], c=y_pred, s=1, alpha=.5)
# Out:
# C:\Users\negat\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py:501: UserWarning: the number of connected components of the connectivity matrix is 128 > 1. Completing it to avoid stopping the tree early.
#   connectivity, n_connected_components = _fix_connectivity(
# <ipython-input-231-b1f3f80f2801>:12: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_pred = ac.labels_.astype(np.int)

# %%
# from sklearn.cluster import DBSCAN

# dbscan = DBSCAN(eps=0.7,
#                 min_samples=10)

# dbscan.fit(X)
# y_pred = dbscan.labels_.astype(np.int)

# %%
data['clusters_pred'] = y_pred

# %%
data
# Out:
#                                               description  dealer  ouner  \
# 0       Все автомобили, представленные в продаже, прох...       1    NaN
# 1       ЛОТ: 01217195\nАвтопрага Север\nДанный автомоб...       1    NaN
# 2       Все автомобили, представленные в продаже, прох...       1    NaN
# 3       КОМПЛЕКТ ЗИМНЕЙ (ЛЕТНЕЙ) РЕЗИНЫ ПО СЕЗОНУ В ПО...       1    NaN
# 4       ЛОТ: 01220889\nАвтопрага Север\n\nВы можете по...       1    NaN
# ...                                                   ...     ...    ...
# 118406                               в наличии, 19 года!!       0    0.0
# 118407  VERRA Автомобили с пробегом работает Online! \...       0    0.0
# 118408  Audi 100 1992 гв \nКузов в достаточно живом со...       0    1.0
# 118409  Хороший семейный автомобиль, очень хорош для п...       0    0.0
# 118410  родная 25-ая ПТС, на ТРАНЗИТАХ!!!\nЖивой кузов...       0    0.0
#
#         ouner2  ouner3  cluster  clusters_pred
# 0          NaN     NaN        2              1
# 1          NaN     NaN        2              2
# 2          NaN     NaN        2              1
# 3          NaN     NaN        2              1
# 4          NaN     NaN        2              2
# ...        ...     ...      ...            ...
# 118406     0.0     0.0        0              3
# 118407     0.0     0.0        0              0
# 118408     1.0     0.0        1              3
# 118409     0.0     0.0        0              3
# 118410     0.0     0.0        0              3
#
# [118328 rows x 7 columns]

# %%
len(y_pred)
# Out:
# 118328

# %%
clust_index = list(data.index)

# %%
clusters = pd.DataFrame(index=clust_index)

# %%
clusters
# Out:
#         clusters
# 0              1
# 1              2
# 2              1
# 3              1
# 4              2
# ...          ...
# 118406         3
# 118407         0
# 118408         3
# 118409         3
# 118410         3
#
# [118328 rows x 1 columns]

# %%
clusters['clusters'] = y_pred

# %%
clusters.to_csv('clusters.csv')

# %%
df = pd.read_csv('clusters.csv')

# %%
df
# Out:
#         Unnamed: 0  clusters
# 0                0         1
# 1                1         2
# 2                2         1
# 3                3         1
# 4                4         2
# ...            ...       ...
# 118323      118406         3
# 118324      118407         0
# 118325      118408         3
# 118326      118409         3
# 118327      118410         3
#
# [118328 rows x 2 columns]
